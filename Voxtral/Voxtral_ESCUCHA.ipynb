# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q "transformers>=4.54.0" "mistral-common[audio]" accelerate librosa bitsandbytes
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.1/43.1 MB 57.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 8.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 139.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 144.9 MB/s eta 0:00:00

# %%
# %cd /content/drive/MyDrive/colab_voxtral
# !ls
# !ls audio | wc -l
# !python3 -c "import json; print(len(json.load(open('ESCUCHA1.json'))), 'items en ESCUCHA1.json')"

# %%
# !python3 run_voxtral_audio_native.py --limit 5

# %%
# !python3 run_voxtral_audio_native.py
